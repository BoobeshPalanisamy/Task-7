# %%
#Data.csv

# %% [markdown]
# **Step 1: Importing the libraries**

# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Step 2: Importing dataset**

# %%
df = pd.read_csv('Data.csv')
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# **Step 3: Handling the missing data**

# %%
print(df.isnull().sum())
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %% [markdown]
# **Step 4: Encoding categorical data**

# %%
label = LabelEncoder()
label.fit(df['Purchased'])
df['Purchased'] = label.transform(df['Purchased'])
df
# Out:
#    Country        Age        Salary  Purchased
# 0   France  44.000000  72000.000000          0
# 1    Spain  27.000000  48000.000000          1
# 2  Germany  30.000000  54000.000000          0
# 3    Spain  38.000000  61000.000000          0
# 4  Germany  40.000000  63777.777778          1
# 5   France  35.000000  58000.000000          1
# 6    Spain  38.777778  52000.000000          0
# 7   France  48.000000  79000.000000          1
# 8  Germany  50.000000  83000.000000          0
# 9   France  37.000000  67000.000000          1

# %% [markdown]
# **Step 5: Creating a dummy variable**

# %%
df = pd.get_dummies(df,columns=['Country'])
df
# Out:
#          Age        Salary  Purchased  Country_France  Country_Germany  \
# 0  44.000000  72000.000000          0               1                0
# 1  27.000000  48000.000000          1               0                0
# 2  30.000000  54000.000000          0               0                1
# 3  38.000000  61000.000000          0               0                0
# 4  40.000000  63777.777778          1               0                1
# 5  35.000000  58000.000000          1               1                0
# 6  38.777778  52000.000000          0               0                0
# 7  48.000000  79000.000000          1               1                0
# 8  50.000000  83000.000000          0               0                1
# 9  37.000000  67000.000000          1               1                0
#
#    Country_Spain
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0
# 5              0
# 6              1
# 7              0
# 8              0
# 9              0

# %% [markdown]
# **Step 6: Splitting the datasets into training sets and Test sets**

# %%
X = df[['Age','Salary','Country_France','Country_Germany','Country_Spain']]
Y = df[['Purchased']]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3)

# %% [markdown]
# **Step 7: Feature Scaling**

# %%
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.57287869,  0.61065894,  1.58113883, -0.63245553, -0.8660254 ],
#        [-1.54282159, -1.25462655, -0.63245553, -0.63245553,  1.15470054],
#        [-1.16946271, -0.78830518, -0.63245553,  1.58113883, -0.8660254 ],
#        [-0.07704231, -0.94374563, -0.63245553, -0.63245553,  1.15470054],
#        [ 1.31959644,  1.46558145, -0.63245553,  1.58113883, -0.8660254 ],
#        [ 1.07069053,  1.15470054,  1.58113883, -0.63245553, -0.8660254 ],
#        [-0.17383905, -0.24426358, -0.63245553, -0.63245553,  1.15470054]])

# %%
x_test
# Out:
# array([[ 0.07506686, -0.02837405, -0.63245553,  1.58113883, -0.8660254 ],
#        [-0.29829201,  0.2220578 ,  1.58113883, -0.63245553, -0.8660254 ],
#        [-0.54719793, -0.47742426,  1.58113883, -0.63245553, -0.8660254 ]])
